# %% [markdown]
# # Demo

# %% [markdown]
# ## Check the camera

# %%
import cv2

cap = cv2.VideoCapture(0)

while True:
    flag,frame=cap.read()
    if flag:
        cv2.imshow("style transfer", frame)

    break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# ...

# %% [markdown]
# ## Import Module

# %%
import test
# Out:
# Loaded matting model "./mat/checkpoints/rvm_mobilenetv3.pth"
# Opened style image "pencil.png"
# Loaded style framework "./style_transfer/test/Model/style_net-TIP-final.pth"

# %% [markdown]
# ## Run the Module

# %%
test.run()
# Out:
# Open Camera
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# QObject::moveToThread: Current thread (0x55b95c0ca6e0) is not the object's thread (0x55b95c77acf0).
# Cannot move to target thread (0x55b95c0ca6e0)
#
# ...
